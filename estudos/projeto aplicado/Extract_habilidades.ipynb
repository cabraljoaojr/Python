# %%
#importando bibliotecas
import pandas as pd

# set de Google Sheets ID e o nome da planilha
sheet_id = "1Q6UcMBiSNvPj09Xj-mcpVq7_EslYBxAB6gmHonDtdwI"
sheet_name = "Prova"

# Criando URL para importar
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# Lendo o dado em um dataframe
df = pd.read_csv(url, skiprows=2)

# Ajustando o cabeçalho do DataFrame
df.columns = ['id', 'questao', 'objetivo', 'alternativa', 'descricao', 'tipo']

# Visualizando DataFrame
df
# Out:
#     id  questao                     objetivo alternativa  \
# 0    1        1  Ordem de resolução númerica           A
# 1    2        1  Ordem de resolução númerica           B
# 2    3        1  Ordem de resolução númerica           C
# 3    4        1  Ordem de resolução númerica           D
# 4    5        1  Ordem de resolução númerica           E
# 5    6        2  Ordem de resolução númerica           A
# 6    7        2  Ordem de resolução númerica           B
# 7    8        2  Ordem de resolução númerica           C
# 8    9        2  Ordem de resolução númerica           D
# 9   10        2  Ordem de resolução númerica           E
# 10  11        3  Ordem de resolução númerica           A
# 11  12        3  Ordem de resolução númerica           B
# 12  13        3  Ordem de resolução númerica           C
# 13  14        3  Ordem de resolução númerica           D
# 14  15        3  Ordem de resolução númerica           E
# 15  16        4  Verificar horas em ponteiro           A
# 16  17        4  Verificar horas em ponteiro           B
# 17  18        4  Verificar horas em ponteiro           C
# 18  19        4  Verificar horas em ponteiro           D
# 19  20        4  Verificar horas em ponteiro           E
# 20  21        5  Verificar horas em ponteiro           A
# 21  22        5  Verificar horas em ponteiro           B
# 22  23        5  Verificar horas em ponteiro           C
# 23  24        5  Verificar horas em ponteiro           D
# 24  25        5  Verificar horas em ponteiro           E
# 25  26        6  Verificar horas em ponteiro           A
# 26  27        6  Verificar horas em ponteiro           B
# 27  28        6  Verificar horas em ponteiro           C
# 28  29        6  Verificar horas em ponteiro           D
# 29  30        6  Verificar horas em ponteiro           E
# 30  31        7          Grandezas e Medidas           A
# 31  32        7          Grandezas e Medidas           B
# 32  33        7          Grandezas e Medidas           C
# 33  34        7          Grandezas e Medidas           D
# 34  35        7          Grandezas e Medidas           E
# 35  36        8          Grandezas e Medidas           A
# 36  37        8          Grandezas e Medidas           B
# 37  38        8          Grandezas e Medidas           C
# 38  39        8          Grandezas e Medidas           D
# 39  40        8          Grandezas e Medidas           E
# 40  41        9          Grandezas e Medidas           A
# 41  42        9          Grandezas e Medidas           B
# 42  43        9          Grandezas e Medidas           C
# 43  44        9          Grandezas e Medidas           D
# 44  45        9          Grandezas e Medidas           E
# 45  46       10          Grandezas e Medidas           A
# 46  47       10          Grandezas e Medidas           B
# 47  48       10          Grandezas e Medidas           C
# 48  49       10          Grandezas e Medidas           D
# 49  50       10          Grandezas e Medidas           E
#
#                                             descricao       tipo
# 0                                         compreendeu    correta
# 1                         verificar uso de parenteses  distrator
# 2                                               chute  distrator
# 3             Verificar ordem de execução da operação  distrator
# 4                    Verificar execuçao das operações  distrator
# 5             Verificar ordem de execução da operação  distrator
# 6                    Verificar execuçao das operações  distrator
# 7                         verificar uso de parenteses  distrator
# 8                                               chute  distrator
# 9                                         compreendeu    correta
# 10                                        compreendeu    correta
# 11                   Verificar execuçao das operações  distrator
# 12            Verificar ordem de execução da operação  distrator
# 13                        verificar uso de parenteses  distrator
# 14                                              chute  distrator
# 15                                              chute  distrator
# 16        Verificar a contagem de minutos em ponteiro  distrator
# 17  Verificar a diferença entre ponteiro de horas ...  distrator
# 18                                        compreendeu    correta
# 19        Verificar a ordem dos números em um relógio  distrator
# 20        Verificar a contagem de minutos em ponteiro  distrator
# 21                                              chute  distrator
# 22        Verificar a ordem dos números em um relógio  distrator
# 23  Verificar a diferença entre ponteiro de horas ...  distrator
# 24                                        compreendeu    correta
# 25        Verificar a ordem dos números em um relógio  distrator
# 26        Verificar a contagem de minutos em ponteiro  distrator
# 27                                        compreendeu    correta
# 28  Verificar a diferença entre ponteiro de horas ...  distrator
# 29                                              chute  distrator
# 30                                        compreendeu    correta
# 31         Verificar diferença entre perímetro e área  distrator
# 32  Verificar cálculo básico para execução da formula  distrator
# 33                   Verificar memorização da formula  distrator
# 34                                              chute  distrator
# 35  Verificar formula para calcular área do trapéz...  distrator
# 36                                        compreendeu    correta
# 37         Verificar diferença entre perímetro e área  distrator
# 38                   Verificar memorização da formula  distrator
# 39                                              chute  distrator
# 40         Verificar diferença entre perímetro e área  distrator
# 41                                              chute  distrator
# 42  Verificar formula para calcular área do hexago...  distrator
# 43                   Verificar memorização da formula  distrator
# 44                                        compreendeu    correta
# 45                                              chute  distrator
# 46                                        compreendeu    correta
# 47         Verificar diferença entre perímetro e área  distrator
# 48  Verificar formula para calcular área do hexago...  distrator
# 49                   Verificar memorização da formula  distrator
